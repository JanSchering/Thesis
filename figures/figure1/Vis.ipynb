# %% [markdown]
# import modules

# %%
import torch as t
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import ticker

# %%
mpl.rcParams['axes.linewidth'] = 1
mpl.rcParams["text.usetex"] = True
mpl.rcParams["font.family"] = "Helvetica"
mpl.rcParams["font.size"] = 12
mpl.rcParams["text.latex.preamble"] = "\\usepackage{amssymb}"

# %%
def remove_ticklines(ax):
    for tic in ax.xaxis.get_major_ticks():
        tic.tick1line.set_visible(False)
        tic.tick2line.set_visible(False)
        tic.label1.set_visible(False)
        tic.label2.set_visible(False)
    for tic in ax.yaxis.get_major_ticks():
        tic.tick1line.set_visible(False)
        tic.tick2line.set_visible(False)
        tic.label1.set_visible(False)
        tic.label2.set_visible(False)

# %%
def create_subfig1(subfig):
    grid = t.zeros(7,7)
    grid[2,3] = 1
    grid[4,3] = 1
    ax = subfig.add_axes([-0.15,0.2,0.7,0.7])

    ax.imshow(grid, cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
    ax.grid(color='black', linewidth=1)
    ax = plt.gca()
    ax.set_xticks(np.arange(.5, 7.5, 1))
    ax.set_yticks(np.arange(.5, 7.5, 1))
    remove_ticklines(ax)
    
    plt.text(7,6.3,"$P(x^{(4,6)}_{t+1} = \\blacksquare) = 1 - (1 - \\beta)$")
    plt.text(7,3.3,"$P(x^{(4,4)}_{t+1} = \\blacksquare) = 1 - (1 - \\beta)^2$")
    plt.text(7,0.3,"$P(x^{(4,2)}_{t+1} = \\square) = 0$")

    ax.annotate('',
                xy = (7,0),
                xytext = (3, 2),
                arrowprops = {
                    'arrowstyle': '-', 'ls': 'dotted'
                },
                horizontalalignment = 'center',
                annotation_clip=False)
    ax.annotate('',
                xy = (7,3),
                xytext = (3, 3),
                arrowprops = {
                    'arrowstyle': '-', 'ls': 'dotted'
                },
                horizontalalignment = 'center',
                annotation_clip=False)
    ax.annotate('',
                xy = (7,6),
                xytext = (3, 5),
                arrowprops = {
                    'arrowstyle': '-', 'ls': 'dotted'
                },
                horizontalalignment = 'center',
                annotation_clip=False)
    ax.set_title("$x_t$")
    return subfig

# %%
def create_subfig2(subfig):
    training_data = t.load("./data/training_set.pt")

    ax1 = subfig.add_axes([0.07, 0.2, 0.18, 0.2])
    remove_ticklines(ax1)
    ax1.text(0.09,0.4,"$f(X,\\beta)$")
    ax1.annotate('',
        xy = (0.5,1),
        xytext = (0.5, 2.3),
        arrowprops = {
            'arrowstyle': '-|>',
            'color': "black"
        },
        horizontalalignment = 'center',
        annotation_clip=False
    )
    ax1.annotate('$\\beta$',
        xy = (0,0.5),
        xytext = (-0.5, 0.4),
        arrowprops = {
            'arrowstyle': '-|>',
            'color': "black"
        },
        horizontalalignment = 'center',
        annotation_clip=False
    )


    ax2 = subfig.add_axes([0.0, 0.84, 0.2, 0.2])
    remove_ticklines(ax2)
    ax2.text(15., -10.5, "$X_t$")
    ax3 = subfig.add_axes([0.05, 0.76, 0.2, 0.2])
    remove_ticklines(ax3)
    ax4 = subfig.add_axes([0.10, 0.68, 0.2, 0.2])
    remove_ticklines(ax4)

    ax2.imshow(training_data[200][0], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
    ax3.imshow(training_data[400][0], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
    ax4.imshow(training_data[500][0], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)

    ax5 = subfig.add_axes([0.32, 0.84, 0.2, 0.2])
    remove_ticklines(ax5)
    ax5.text(6., -10.5, "$X_{t+1}$")
    ax6 = subfig.add_axes([0.37, 0.76, 0.2, 0.2])
    remove_ticklines(ax6)
    ax7 = subfig.add_axes([0.42, 0.68, 0.2, 0.2])
    remove_ticklines(ax7)

    ax5.imshow(training_data[200][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
    ax6.imshow(training_data[400][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
    ax7.imshow(training_data[500][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)

    ax8 = subfig.add_axes([0.32, 0.22, 0.2, 0.2])
    remove_ticklines(ax8)
    ax8.text(6., -10.5, "$\hat{X}_{t+1}$")
    ax9 = subfig.add_axes([0.37, 0.16, 0.2, 0.2])
    remove_ticklines(ax9)
    ax10 = subfig.add_axes([0.42, 0.08, 0.2, 0.2])
    remove_ticklines(ax10)

    ax8.imshow(training_data[195][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
    ax9.imshow(training_data[405][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
    ax10.imshow(training_data[505][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)

    ax4.annotate('',
        xy = (134,10.),
        xytext = (64., 10),
        arrowprops = {
            'arrowstyle': '-|>',
            'color': "black"
        },
        horizontalalignment = 'center',
        annotation_clip=False
    )
    ax1.annotate('',
        xy = (1.65,0.5),
        xytext = (1,0.5),
        arrowprops = {
            'arrowstyle': '-|>',
            'color': "black"
        },
        horizontalalignment = 'center',
        annotation_clip=False
    )

    ax10 = subfig.add_axes([0.52, 0.48, 0.52, 0.145])
    remove_ticklines(ax10)
    ax10.text(0.02,0.35,"$\mathcal{L}(\\beta) = MSE(\hat{X}_{t+1}, X_{t+1})$")

    ax10.annotate('',
        xy = (0.12,-1.29),
        xytext = (0.5,0.),
        arrowprops = {
            'arrowstyle': '<|-',
            'color': "black",
            'connectionstyle': "angle",
        },
        horizontalalignment = 'center',
        annotation_clip=False
    )

    ax10.annotate('',
        xy = (0.12,2.61),
        xytext = (0.5,1),
        arrowprops = {
            'arrowstyle': '<|-',
            'color': "black",
            'connectionstyle': "angle",
        },
        horizontalalignment = 'center',
        annotation_clip=False
    )
    return subfig

# %%
def create_subfig3(subfig):
    num_datapoints = 2000
    dist_hist = np.load("./data/sample_based/losses.npy")
    beta_hist = np.load("./data/sample_based/param_trace.npy")
    print(beta_hist.shape)
    print(dist_hist.shape)

    axs = subfig.subplots()
    axs.set_xlabel("gradient steps")

    color = 'darkblue'
    axs.plot(beta_hist[:num_datapoints], color=color)
    axs.set_ylabel("$\\beta$", color=color)
    axs.set_yscale("linear")
    axs.minorticks_off()
    axs.tick_params(axis='y', labelcolor=color)

    color = 'r'
    axs2 = axs.twinx()
    axs2.set_ylim((0, 1.2e4))
    axs2.set_ylabel("$\mathcal{L}(\\beta|X)$", color=color)
    axs2.plot(dist_hist[:num_datapoints], color=color)
    axs2.tick_params(axis='y', labelcolor=color)
    formatter = ticker.ScalarFormatter(useMathText=True)
    formatter.set_scientific(True) 
    formatter.set_powerlimits((-1,1)) 
    axs2.yaxis.set_major_formatter(formatter)

# %%
def create_subfig4(subfig):
    num_datapoints = 2000
    likelihood_hist = np.load("./data/likelihood_based/losses.npy")
    beta_hist = np.load("./data/likelihood_based/param_trace.npy")

    axs = subfig.subplots()
    #axs.set_xlabel("gradient steps")

    color = 'darkblue'
    axs.plot(beta_hist[:num_datapoints], color=color)
    axs.set_ylabel("$\\beta$", color=color)
    axs.set_yscale("linear")
    axs.minorticks_off()
    axs.tick_params(axis='y', labelcolor=color)
    
    color = 'r'
    axs2 = axs.twinx()
    axs2.set_ylim((0, 1.2e4))
    axs2.set_ylabel("$ - \log P(X_{t+1}|X_t, \\beta)$", color=color)
    axs2.plot(likelihood_hist[:num_datapoints], color=color)
    axs2.tick_params(axis='y', labelcolor=color)
    formatter = ticker.ScalarFormatter(useMathText=True)
    formatter.set_scientific(True) 
    formatter.set_powerlimits((-1,0)) 
    axs2.yaxis.set_major_formatter(formatter)

# %% [markdown]
# # Putting everything together

# %%
fig = plt.figure(layout='constrained', figsize=(7,4), dpi=300)
subfigs = fig.subfigures(2, 2, wspace=0.07, hspace=0.12, width_ratios=[1.2,1])

create_subfig1(subfigs[0,0])
create_subfig2(subfigs[1,0])
create_subfig3(subfigs[1,1])
create_subfig4(subfigs[0,1])

fig.text(0,1,"\\textbf{A}")
fig.text(0,0.5,"\\textbf{B}")
fig.text(0.55,1,"\\textbf{C}")
fig.text(0.55,0.5,"\\textbf{D}")

plt.show()
# Out:
# (4550,)
# (4550,)

# %% [markdown]
# # Alternative Figure: Likelihood contours + Sample-based training, smaller graphics

# %%
fig = plt.figure(layout="constrained", figsize=(12, 3), dpi=300)
subfigs = fig.subfigures(1,3, wspace=0.05, width_ratios=[1,1,1.2])

#####
###
###     Subfigure 1: Model overview
###
#####
subfigs[0].text(0,1,r"\textbf{A}")

grid = t.zeros(7,7)
grid[3,2] = 1
grid[3,4] = 1
ax = subfigs[0].add_axes([0,0.2,0.4,0.4])

ax.imshow(grid, cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
ax.grid(color='black', linewidth=1)
ax = plt.gca()
ax.set_xticks(np.arange(.5, 7.5, 1))
ax.set_yticks(np.arange(.5, 7.5, 1))
remove_ticklines(ax)

grid[3,3] = 1
grid[4,3] = 1
grid_after = subfigs[0].add_axes([0.6,0.2,0.4,0.4])
grid_after.imshow(grid, cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
grid_after.grid(color='black', linewidth=1)
grid_after.set_xticks(np.arange(.5, 7.5, 1))
grid_after.set_yticks(np.arange(.5, 7.5, 1))
remove_ticklines(grid_after)

ax.annotate('',
            xy = (1,-5.5),
            xytext = (1, 3),
            arrowprops = {
                'arrowstyle': '-', 'ls': 'dotted'
            },
            horizontalalignment = 'center',
            annotation_clip=False)
ax.annotate('',
            xy = (3,-3.5),
            xytext = (3, 3),
            arrowprops = {
                'arrowstyle': '-', 'ls': 'dotted'
            },
            horizontalalignment = 'center',
            annotation_clip=False)
ax.annotate('',
            xy = (5,-1.5),
            xytext = (4, 3),
            arrowprops = {
                'arrowstyle': '-', 'ls': 'dotted'
            },
            horizontalalignment = 'center',
            annotation_clip=False)
ax.annotate('',
            xy = (12.,3),
            xytext = (6.8, 3),
            arrowprops = {
                'arrowstyle': '->',
                'lw': 3
            },
            horizontalalignment = 'center',
            annotation_clip=False)

ax.text(2.7,7.5,r"$x_t$", clip_on=False)
grid_after.text(2.2,7.5,r"$x_{t+1}$", clip_on=False)

ax.text(1,-5.5,"$P(x^{(2,4)}_{t+1} = \\blacksquare) = 1 - (1 - \\beta)$")
ax.text(3,-3.5,"$P(x^{(4,4)}_{t+1} = \\blacksquare) = 1 - (1 - \\beta)^2$")
ax.text(5,-1.5,"$P(x^{(5,4)}_{t+1} = \\square) = 0$")

#####
###
###     Subfigure 2: Training process
###
#####
subfigs[1].text(0,1,r"\textbf{B}")

beta_block = subfigs[1].add_axes([0.03,0.3,0.1,0.1])
beta_block.axis("off")
beta_block.text(
        0.5,
        0.5,
        r"$\beta$",
        horizontalalignment='center',
        verticalalignment='center',
        transform=beta_block.transAxes)
beta_outline = mpl.patches.Circle((0.5,0.5),0.7, fill=False, clip_on=False)
beta_block.add_patch(beta_outline)
beta_block.annotate('',
        xy = (2.7,0.5),
        xytext = (1.2, 0.5),
        arrowprops = {
            'arrowstyle': '->',
        },
        horizontalalignment = 'center',
        annotation_clip=False
)

training_data = t.load("./data/training_set.pt")

stack_xt_start = subfigs[1].add_axes([0.0, 0.75, 0.1, 0.1])
stack_xt_start.imshow(training_data[200][0], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt_start)
stack_xt_mid = subfigs[1].add_axes([0.03, 0.72, 0.1, 0.1])
stack_xt_mid.imshow(training_data[400][0], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt_mid)
stack_xt_end = subfigs[1].add_axes([0.06, 0.69, 0.1, 0.1])
stack_xt_end.imshow(training_data[500][0], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt_end)
stack_xt_end.annotate('',
        xy = (180.,240),
        xytext = (64., 64),
        arrowprops = {
            'arrowstyle': '->',
        },
        horizontalalignment = 'center',
        annotation_clip=False
)
stack_xt_end.annotate('',
        xy = (450.,0),
        xytext = (64., 0),
        arrowprops = {
            'arrowstyle': '->',
        },
        horizontalalignment = 'center',
        annotation_clip=False
)
stack_xt_mid.text(
    32,-36,
    r"$X_{t}$",
    clip_on = False,
    horizontalalignment = 'center'
)

stack_xt2_start = subfigs[1].add_axes([0.65, 0.75, 0.1, 0.1])
stack_xt2_start.imshow(training_data[200][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt2_start)
stack_xt2_mid = subfigs[1].add_axes([0.68, 0.72, 0.1, 0.1])
stack_xt2_mid.imshow(training_data[400][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt2_mid)
stack_xt2_end = subfigs[1].add_axes([0.71, 0.69, 0.1, 0.1])
stack_xt2_end.imshow(training_data[500][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt2_end)
stack_xt2_mid.annotate('',
        xy = (32.,140),
        xytext = (32.,85),
        arrowprops = {
            'arrowstyle': '->',
        },
        horizontalalignment = 'center',
        annotation_clip=False
)
stack_xt2_mid.text(
    32,-36,
    r"$X_{t+1}$",
    clip_on = False,
    horizontalalignment = 'center'
)

stack_xt3_start = subfigs[1].add_axes([0.65, 0.33, 0.1, 0.1])
stack_xt3_start.imshow(training_data[195][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt3_start)
stack_xt3_mid = subfigs[1].add_axes([0.68, 0.3, 0.1, 0.1])
stack_xt3_mid.imshow(training_data[405][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt3_mid)
stack_xt3_end = subfigs[1].add_axes([0.71, 0.27, 0.1, 0.1])
stack_xt3_end.imshow(training_data[505][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt3_end)
stack_xt3_mid.annotate('',
        xy = (32.,-65),
        xytext = (32.,-21),
        arrowprops = {
            'arrowstyle': '->',
        },
        horizontalalignment = 'center',
        annotation_clip=False
)
stack_xt3_mid.text(
    32,124,
    r"$\hat{X}_{t+1}$",
    clip_on = False,
    horizontalalignment = 'center'
)

fx_block = subfigs[1].add_axes([0.3,0.3,0.2,0.1])
remove_ticklines(fx_block)
fx_block.text(
        0.5,
        0.5,
        r"$f(X|\beta)$",
        horizontalalignment='center',
        verticalalignment='center',
        transform=fx_block.transAxes)
fx_block.annotate('',
        xy = (1.8,0.5),
        xytext = (1, 0.5),
        arrowprops = {
            'arrowstyle': '->',
        },
        horizontalalignment = 'center',
        annotation_clip=False
)

mse_block = subfigs[1].add_axes([0.48,0.5,0.52,0.1])
remove_ticklines(mse_block)
mse_block.text(
        0.5,
        0.5,
        r"$\mathcal{L}(\beta) = MSE(\hat{X}_{t+1}, X_{t+1})$",
        horizontalalignment='center',
        verticalalignment='center',
        transform=mse_block.transAxes)
mse_block.annotate('',
        xy = (-0.77,-2.2),
        xytext = (0.8,-3.5),
        arrowprops = {
            'arrowstyle': '-|>',
            'color': "black",
            'connectionstyle': "angle,angleA=-180,angleB=90",
        },
        horizontalalignment = 'center',
        annotation_clip=False
    )
mse_block.annotate('',
        xy = (0.793,0.),
        xytext = (0.793,-3.6),
        arrowprops = {
            'arrowstyle': '-',
            'color': "black",
        },
        horizontalalignment = 'center',
        annotation_clip=False
    )


#####
###
###     Subfigure: training results
###
#####
subfigs[2].text(0,1,r"\textbf{C}")
import pandas as pd

num_datapoints = 2000
dist_hist = np.load("./data/sample_based/losses2.npy")
dist_hist = pd.DataFrame(dist_hist)
beta_hist = np.load("./data/sample_based/param_trace2.npy")
reference_betas = np.load("./data/likelihood_based/param_trace2.npy")
reference_dist = np.load("./data/likelihood_based/losses2.npy")
local_opt = reference_betas[np.argmin(reference_dist)]
print(beta_hist.shape)
print(dist_hist.shape)

axs = subfigs[2].subplots()
axs.set_xlabel("gradient steps")

color = 'darkblue'
axs.plot(beta_hist[:num_datapoints], color=color)
axs.set_ylabel("$\\beta$", color=color)
axs.set_yscale("linear")
axs.minorticks_off()
axs.tick_params(axis='y', labelcolor=color)
axs.set_ylim(0,1)

axs.hlines(y=local_opt, xmin=0, xmax=num_datapoints, linestyle="dotted", color="black", label="likelihood-based optimum")
axs.legend()

color = 'r'
axs2 = axs.twinx()
#axs2.set_ylim((0, 1.2e4))
axs2.set_ylabel("$\mathcal{L}(\\beta|X)$", color=color)
axs2.plot(dist_hist.iloc[:num_datapoints], color="pink", alpha=0.3)
axs2.plot(dist_hist.iloc[:num_datapoints].rolling(10).mean(), color="red")
axs2.tick_params(axis='y', labelcolor=color)
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
axs2.yaxis.set_major_formatter(formatter) 
    
plt.show()
# Out:
# (4550,)
# (4550, 1)

# %%
fig = plt.figure(layout="constrained", figsize=(4, 3), dpi=300)

#####
###
###     Subfigure 1: Model overview
###
#####
#fig.text(0,1,r"\textbf{A}")

grid = t.zeros(7,7)
grid[3,2] = 1
grid[3,4] = 1
ax = fig.add_axes([0,0.2,0.4,0.4])

ax.imshow(grid, cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
ax.grid(color='black', linewidth=1)
ax = plt.gca()
ax.set_xticks(np.arange(.5, 7.5, 1))
ax.set_yticks(np.arange(.5, 7.5, 1))
remove_ticklines(ax)

grid[3,3] = 1
grid[4,3] = 1
grid_after = fig.add_axes([0.6,0.2,0.4,0.4])
grid_after.imshow(grid, cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
grid_after.grid(color='black', linewidth=1)
grid_after.set_xticks(np.arange(.5, 7.5, 1))
grid_after.set_yticks(np.arange(.5, 7.5, 1))
remove_ticklines(grid_after)

ax.annotate('',
            xy = (1,-5.5),
            xytext = (1, 3),
            arrowprops = {
                'arrowstyle': '-', 'ls': 'dotted'
            },
            horizontalalignment = 'center',
            annotation_clip=False)
ax.annotate('',
            xy = (3,-3.5),
            xytext = (3, 3),
            arrowprops = {
                'arrowstyle': '-', 'ls': 'dotted'
            },
            horizontalalignment = 'center',
            annotation_clip=False)
ax.annotate('',
            xy = (5,-1.5),
            xytext = (4, 3),
            arrowprops = {
                'arrowstyle': '-', 'ls': 'dotted'
            },
            horizontalalignment = 'center',
            annotation_clip=False)
ax.annotate('',
            xy = (12.,3),
            xytext = (6.8, 3),
            arrowprops = {
                'arrowstyle': '->',
                'lw': 3
            },
            horizontalalignment = 'center',
            annotation_clip=False)

ax.text(2.7,7.5,r"$x_t$", clip_on=False)
grid_after.text(2.2,7.5,r"$x_{t+1}$", clip_on=False)

ax.text(1,-5.5,"$P(x^{(2,4)}_{t+1} = \\blacksquare) = 1 - (1 - \\beta)$")
ax.text(3,-3.5,"$P(x^{(4,4)}_{t+1} = \\blacksquare) = 1 - (1 - \\beta)^2$")
ax.text(5,-1.5,"$P(x^{(5,4)}_{t+1} = \\square) = 0$")
# Out:
# Text(5, -1.5, '$P(x^{(5,4)}_{t+1} = \\square) = 0$')
# c:\Users\jsche\anaconda3\envs\testenv\lib\site-packages\IPython\core\events.py:93: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   func(*args, **kwargs)
# c:\Users\jsche\anaconda3\envs\testenv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig = plt.figure(layout="constrained", figsize=(4, 3), dpi=300)

beta_block = fig.add_axes([0.03,0.3,0.1,0.1])
beta_block.axis("off")
beta_block.text(
        0.5,
        0.5,
        r"$\beta$",
        horizontalalignment='center',
        verticalalignment='center',
        transform=beta_block.transAxes)
beta_outline = mpl.patches.Circle((0.5,0.5),0.7, fill=False, clip_on=False)
beta_block.add_patch(beta_outline)
beta_block.annotate('',
        xy = (2.7,0.5),
        xytext = (1.2, 0.5),
        arrowprops = {
            'arrowstyle': '->',
        },
        horizontalalignment = 'center',
        annotation_clip=False
)

training_data = t.load("./data/training_set.pt")

stack_xt_start = fig.add_axes([0.0, 0.75, 0.1, 0.1])
stack_xt_start.imshow(training_data[200][0], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt_start)
stack_xt_mid = fig.add_axes([0.03, 0.72, 0.1, 0.1])
stack_xt_mid.imshow(training_data[400][0], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt_mid)
stack_xt_end = fig.add_axes([0.06, 0.69, 0.1, 0.1])
stack_xt_end.imshow(training_data[500][0], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt_end)
stack_xt_end.annotate('',
        xy = (180.,240),
        xytext = (64., 64),
        arrowprops = {
            'arrowstyle': '->',
        },
        horizontalalignment = 'center',
        annotation_clip=False
)
stack_xt_end.annotate('',
        xy = (450.,0),
        xytext = (64., 0),
        arrowprops = {
            'arrowstyle': '->',
        },
        horizontalalignment = 'center',
        annotation_clip=False
)
stack_xt_mid.text(
    32,-36,
    r"$X_{t}$",
    clip_on = False,
    horizontalalignment = 'center'
)

stack_xt2_start = fig.add_axes([0.65, 0.75, 0.1, 0.1])
stack_xt2_start.imshow(training_data[200][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt2_start)
stack_xt2_mid = fig.add_axes([0.68, 0.72, 0.1, 0.1])
stack_xt2_mid.imshow(training_data[400][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt2_mid)
stack_xt2_end = fig.add_axes([0.71, 0.69, 0.1, 0.1])
stack_xt2_end.imshow(training_data[500][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt2_end)
stack_xt2_mid.annotate('',
        xy = (32.,140),
        xytext = (32.,85),
        arrowprops = {
            'arrowstyle': '->',
        },
        horizontalalignment = 'center',
        annotation_clip=False
)
stack_xt2_mid.text(
    32,-36,
    r"$X_{t+1}$",
    clip_on = False,
    horizontalalignment = 'center'
)

stack_xt3_start = fig.add_axes([0.65, 0.33, 0.1, 0.1])
stack_xt3_start.imshow(training_data[195][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt3_start)
stack_xt3_mid = fig.add_axes([0.68, 0.3, 0.1, 0.1])
stack_xt3_mid.imshow(training_data[405][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt3_mid)
stack_xt3_end = fig.add_axes([0.71, 0.27, 0.1, 0.1])
stack_xt3_end.imshow(training_data[505][1], cmap="Greys", interpolation="nearest", vmin=0, vmax=1)
remove_ticklines(stack_xt3_end)
stack_xt3_mid.annotate('',
        xy = (32.,-65),
        xytext = (32.,-21),
        arrowprops = {
            'arrowstyle': '->',
        },
        horizontalalignment = 'center',
        annotation_clip=False
)
stack_xt3_mid.text(
    32,124,
    r"$\hat{X}_{t+1}$",
    clip_on = False,
    horizontalalignment = 'center'
)

fx_block = fig.add_axes([0.3,0.3,0.2,0.1])
remove_ticklines(fx_block)
fx_block.text(
        0.5,
        0.5,
        r"$f(X|\beta)$",
        horizontalalignment='center',
        verticalalignment='center',
        transform=fx_block.transAxes)
fx_block.annotate('',
        xy = (1.8,0.5),
        xytext = (1, 0.5),
        arrowprops = {
            'arrowstyle': '->',
        },
        horizontalalignment = 'center',
        annotation_clip=False
)

mse_block = fig.add_axes([0.48,0.5,0.52,0.1])
remove_ticklines(mse_block)
mse_block.text(
        0.5,
        0.5,
        r"$\mathcal{L}(\beta) = MSE(\hat{X}_{t+1}, X_{t+1})$",
        horizontalalignment='center',
        verticalalignment='center',
        transform=mse_block.transAxes)
mse_block.annotate('',
        xy = (-0.77,-2.2),
        xytext = (0.8,-3.5),
        arrowprops = {
            'arrowstyle': '-|>',
            'color': "black",
            'connectionstyle': "angle,angleA=-180,angleB=90",
        },
        horizontalalignment = 'center',
        annotation_clip=False
    )
mse_block.annotate('',
        xy = (0.793,0.),
        xytext = (0.793,-3.6),
        arrowprops = {
            'arrowstyle': '-',
            'color': "black",
        },
        horizontalalignment = 'center',
        annotation_clip=False
    )
# Out:
# Text(0.793, -3.6, '')
# c:\Users\jsche\anaconda3\envs\testenv\lib\site-packages\IPython\core\events.py:93: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   func(*args, **kwargs)
# c:\Users\jsche\anaconda3\envs\testenv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig = plt.figure(layout="constrained", figsize=(4, 3), dpi=300)
import pandas as pd

num_datapoints = 2000
dist_hist = np.load("./data/sample_based/losses2.npy")
dist_hist = pd.DataFrame(dist_hist)
beta_hist = np.load("./data/sample_based/param_trace2.npy")
reference_betas = np.load("./data/likelihood_based/param_trace2.npy")
reference_dist = np.load("./data/likelihood_based/losses2.npy")
local_opt = reference_betas[np.argmin(reference_dist)]
print(beta_hist.shape)
print(dist_hist.shape)

axs = fig.subplots()
axs.set_xlabel("gradient steps")

color = 'darkblue'
axs.plot(beta_hist[:num_datapoints], color=color)
axs.set_ylabel("$\\beta$", color=color)
axs.set_yscale("linear")
axs.minorticks_off()
axs.tick_params(axis='y', labelcolor=color)
axs.set_ylim(0,1)

axs.hlines(y=local_opt, xmin=0, xmax=num_datapoints, linestyle="dotted", color="black", label="likelihood-based optimum")
axs.legend()

color = 'r'
axs2 = axs.twinx()
#axs2.set_ylim((0, 1.2e4))
axs2.set_ylabel("$\mathcal{L}(\\beta|X)$", color=color)
axs2.plot(dist_hist.iloc[:num_datapoints], color="pink", alpha=0.3)
axs2.plot(dist_hist.iloc[:num_datapoints].rolling(10).mean(), color="red")
axs2.tick_params(axis='y', labelcolor=color)
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
axs2.yaxis.set_major_formatter(formatter)
# Out:
# (4550,)
# (4550, 1)

# %%
fig = plt.figure(layout="constrained", figsize=(4, 3), dpi=300)
subfigs = fig.subfigures(2,1, height_ratios=[1,1.3])
import pandas as pd

num_datapoints = 2000
dist_hist = np.load("./data/sample_based/losses.npy")
dist_hist = pd.DataFrame(dist_hist)
beta_hist = np.load("./data/sample_based/param_trace.npy")
reference_betas = np.load("./data/likelihood_based/param_trace.npy")
reference_dist = np.load("./data/likelihood_based/losses.npy")
local_opt = reference_betas[np.argmin(reference_dist)]
print(beta_hist.shape)
print(dist_hist.shape)

axs = subfigs[0].subplots()

color = 'darkblue'
axs.plot(beta_hist[:num_datapoints], color=color)
axs.set_ylabel("$\\beta$")
axs.set_yscale("linear")
axs.minorticks_off()
axs.tick_params(axis='y')
axs.set_ylim(0,1)

axs.hlines(y=local_opt, xmin=0, xmax=num_datapoints, linestyle="dotted", color="black", label="likelihood-based optimum")
axs.legend()
for tic in axs.xaxis.get_major_ticks():
        tic.tick1line.set_visible(False)
        tic.tick2line.set_visible(False)
        tic.label1.set_visible(False)
        tic.label2.set_visible(False)

color = 'r'
axs2 = subfigs[1].subplots()
#axs2.set_ylim((0, 1.2e4))
axs2.set_ylabel("$\mathcal{L}(\\beta|X)$")
axs2.plot(dist_hist.iloc[:num_datapoints], color="pink", alpha=0.3)
axs2.plot(dist_hist.iloc[:num_datapoints].rolling(10).mean(), color="red")
axs2.tick_params(axis='y')
formatter = ticker.ScalarFormatter(useMathText=False)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,2)) 
axs2.yaxis.set_major_formatter(formatter) 
axs2.set_xlabel("gradient steps")

axs2.set_yticks([0.,1000.], [r"$0.0$", r"$1.0$"])
axs2.text(-100,1800,r"$\times10^3$")
# Out:
# (4550,)
# (4550, 1)
# Text(-100, 1800, '$\\times10^3$')

# %%
beta_hist = np.load("./data/sample_based/param_trace.npy")
beta_hist_t = np.load("./data/sample_based/param_trace_t.npy")

# %%
beta_hist_t
# Out:
# array([0.47869915, 0.47875485, 0.47884858, ..., 0.48585624, 0.48579153,
#        0.4858655 ], dtype=float32)

# %%
beta_hist
# Out:
# array([0.79744744, 0.7969518 , 0.7965408 , ..., 0.48858503, 0.48861253,
#        0.4886187 ], dtype=float32)
